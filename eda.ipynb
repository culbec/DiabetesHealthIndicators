# %%
import json
import pathlib

from dhi.utils import get_logger

SUBJECT = "DiabetesHealthIndicators"
CONFIG_PATH = pathlib.Path("config.json").resolve()

log = get_logger(SUBJECT)

try:
    log.info(f"Loading configuration from {CONFIG_PATH}...")
    with open(CONFIG_PATH, "r") as config_file:
        CONFIG = json.load(config_file)
    log.info("Configuration loaded successfully.")
except Exception as e:
    log.error(f"Failed to load configuration: {e}")
    CONFIG = {}
    
subject_config = CONFIG.get(SUBJECT, {})
LOADER_CONFIG = subject_config.get("loader", {})
# Out:
# [2025-11-12 21:44:55,582] - DiabetesHealthIndicators - [INFO] - Loading configuration from /home/culbec/uni/DiabetesHealthIndicators/config.json...
# [2025-11-12 21:44:55,582] - DiabetesHealthIndicators - [INFO] - Configuration loaded successfully.

# %%
from dhi.data.loader.dhi_loader import DHILoader

loader = DHILoader(**LOADER_CONFIG)
try:
    df = loader.load()
    log.info("Data loaded successfully.")
except Exception as e:
    log.error(f"Failed to load data: {e}")
    raise e
# Out:
# [2025-11-12 21:44:57,024] - DHILoader - [INFO] - Loading dataset from path: /home/culbec/uni/DiabetesHealthIndicators/.datasets/diabetes_health_indicators/diabetes_dataset.csv
# [2025-11-12 21:44:57,096] - DHILoader - [INFO] - Removing unnamed columns from the dataset
# [2025-11-12 21:44:57,101] - DHILoader - [INFO] - Removing instances with all NaN values
# [2025-11-12 21:44:57,115] - DHILoader - [INFO] - Reducing memory usage of the dataset
# [2025-11-12 21:44:57,116] - DHILoader - [INFO] - Initial memory usage of dataframe is 23.65 MB
# [2025-11-12 21:44:57,118] - DHILoader - [WARNING] - Column 'gender' is not numeric and was not downcasted
# [2025-11-12 21:44:57,119] - DHILoader - [WARNING] - Column 'ethnicity' is not numeric and was not downcasted
# [2025-11-12 21:44:57,119] - DHILoader - [WARNING] - Column 'education_level' is not numeric and was not downcasted
# [2025-11-12 21:44:57,119] - DHILoader - [WARNING] - Column 'income_level' is not numeric and was not downcasted
# [2025-11-12 21:44:57,119] - DHILoader - [WARNING] - Column 'employment_status' is not numeric and was not downcasted
# [2025-11-12 21:44:57,119] - DHILoader - [WARNING] - Column 'smoking_status' is not numeric and was not downcasted
# [2025-11-12 21:44:57,124] - DHILoader - [WARNING] - Column 'diabetes_stage' is not numeric and was not downcasted
# [2025-11-12 21:44:57,125] - DHILoader - [INFO] - Final memory usage of dataframe is 9.06 MB
# [2025-11-12 21:44:57,125] - DHILoader - [INFO] - Decreased memory usage by 61.69%
# [2025-11-12 21:44:57,125] - DHILoader - [INFO] - Function '_reduce_memory_usage' executed in 0.01036012 seconds.
# [2025-11-12 21:44:57,127] - DHILoader - [INFO] - Function 'load' executed in 0.10248311 seconds.
# [2025-11-12 21:44:57,127] - DiabetesHealthIndicators - [INFO] - Data loaded successfully.
